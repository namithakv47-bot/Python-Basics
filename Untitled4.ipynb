# %% [markdown]
# <a href="https://colab.research.google.com/github/namithakv47-bot/Python-Basics/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[1,2,3,4,5]
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
a=[1,2,3,4,5]
a.append(6)
print(a)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a=[1,2,3,4,5,6]
a.pop
print(a)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a=[1,2,3,4,5]
a.remove(3)
print(a)
# Out:
# [1, 2, 4, 5]

# %%
a=[1,2,4,5]
a.insert(2,3)
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
a=(1,2,3,4,5)
print(a)
# Out:
# (1, 2, 3, 4, 5)

# %%
a=(1,2,3,4,5)
b=list(a)
b.append(6)
a=tuple(b)
print(a)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
a={1,2,3,4,5}
print(a)
# Out:
# {1, 2, 3, 4, 5}

# %%
a={1,2,3,4,5}
a.add(6)
print(a)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
a={1,2,3,4,5}
a.remove(5)
print(a)
# Out:
# {1, 2, 3, 4}
